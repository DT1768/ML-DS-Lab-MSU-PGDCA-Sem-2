# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../input/random-data/Random Data.csv',header = 0)
print("Mean",df.mean())
print("Median",df.median())
print("Standard Deviation",df.std())

ax = df.plot.kde()
# Out:
# Mean Data    461.426471
# dtype: float64
# Median Data    456.5
# dtype: float64
# Standard Deviation Data    282.728364
# dtype: float64
